# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
import statsmodels.api as sm

# %%
df = pd.read_csv("datasets/processed_data_with_stages.csv")
df = df.rename(columns={"Unnamed: 0":"Timestamp"})

# %%
df.head()

# %% [markdown]
# ### AutoCorrelation, Partial Autocorrelation, Cross-Correlation

# %%
plt.figure(figsize=(12,8))


ax1=plt.subplot(2, 2, 1)
sns.set_style("darkgrid")
plot_acf(df['DAC'].values,lags=50,ax=ax1, color="#c6474b", vlines_kwargs={"colors": "#c6474b"})
plt.xlabel('')
plt.ylabel("")
sns.despine()
plt.title("DAC (Algoritmo de Disciplinado)")


ax2=plt.subplot(2, 2, 2)

sns.set_style("darkgrid")
plot_acf(df['Phase Error'].values,lags=50,ax=ax2, color="#c6474b", vlines_kwargs={"colors": "#c6474b"})
plt.xlabel('')
plt.ylabel("")
plt.title("Error de Fase (Phase Error)")
sns.despine()

ax3=plt.subplot(2, 2, 3)

sns.set_style("darkgrid")
plot_acf(df['Temperature'].values,lags=50,ax=ax3, color="#c6474b", vlines_kwargs={"colors": "#c6474b"})
plt.xlabel('')
plt.ylabel("")
plt.title("Temperatura")
sns.despine()

ax4=plt.subplot(2, 2, 4)

sns.set_style("darkgrid")
plot_acf(df['Frequency Error'].values,lags=50,ax=ax4, color="#c6474b", vlines_kwargs={"colors": "#c6474b"})
plt.xlabel('')
plt.ylabel("")
plt.title("Error de Frecuencia (Frequency Error)")
sns.despine()

plt.suptitle("Autocorrelación", fontsize=18)
plt.tight_layout()

#plt.savefig("fotos/autocorrelacion_4variables.png")

# %%
plt.figure(figsize=(12,8))


ax1=plt.subplot(2, 2, 1)
sns.set_style("darkgrid")
plot_pacf(df['DAC'].values,lags=50,ax=ax1, color="#c6474b", vlines_kwargs={"colors": "#c6474b"})
plt.xlabel('')
plt.ylabel("")
sns.despine()
plt.title("DAC (Algoritmo de Disciplinado)")


ax2=plt.subplot(2, 2, 2)

sns.set_style("darkgrid")
plot_pacf(df['Phase Error'].values,lags=50,ax=ax2, color="#c6474b", vlines_kwargs={"colors": "#c6474b"})
plt.xlabel('')
plt.ylabel("")
plt.title("Error de Fase (Phase Error)")
sns.despine()

ax3=plt.subplot(2, 2, 3)

sns.set_style("darkgrid")
plot_pacf(df['Temperature'].values,lags=50,ax=ax3, color="#c6474b", vlines_kwargs={"colors": "#c6474b"})
plt.xlabel('')
plt.ylabel("")
plt.title("Temperatura")
sns.despine()

ax4=plt.subplot(2, 2, 4)

sns.set_style("darkgrid")
plot_pacf(df['Frequency Error'].values,lags=50,ax=ax4, color="#c6474b", vlines_kwargs={"colors": "#c6474b"})
plt.xlabel('')
plt.ylabel("")
plt.title("Error de Frecuencia (Frequency Error)")
sns.despine()

plt.suptitle("Autocorrelación Parcial", fontsize=18)
plt.tight_layout()

#plt.savefig("fotos/partial_autocorrelacion_4variables.png")

# %%
plt.figure(figsize=(12,8))


ax1=plt.subplot(2, 2, 1)
sns.set_style("darkgrid")
plot_acf(df['DAC'].diff().iloc[1:].values,lags=50,ax=ax1, color="#c6474b", vlines_kwargs={"colors": "#c6474b"})
plt.xlabel('')
plt.ylabel("")
sns.despine()
plt.title("DAC (Algoritmo de Disciplinado)")


ax2=plt.subplot(2, 2, 2)

sns.set_style("darkgrid")
plot_acf(df['Phase Error'].diff().iloc[1:].values,lags=50,ax=ax2, color="#c6474b", vlines_kwargs={"colors": "#c6474b"})
plt.xlabel('')
plt.ylabel("")
plt.title("Error de Fase (Phase Error)")
sns.despine()

ax3=plt.subplot(2, 2, 3)

sns.set_style("darkgrid")
plot_acf(df['Temperature'].diff().iloc[1:].values,lags=50,ax=ax3, color="#c6474b", vlines_kwargs={"colors": "#c6474b"})
plt.xlabel('')
plt.ylabel("")
plt.title("Temperatura")
sns.despine()

ax4=plt.subplot(2, 2, 4)

sns.set_style("darkgrid")
plot_acf(df['Frequency Error'].diff().iloc[1:].values,lags=50,ax=ax4, color="#c6474b", vlines_kwargs={"colors": "#c6474b"})
plt.xlabel('')
plt.ylabel("")
plt.title("Error de Frecuencia (Frequency Error)")
sns.despine()

plt.suptitle("Autocorrelación (Diferencia)", fontsize=18)
plt.tight_layout()

#plt.savefig("fotos/diff_autocorrelacion.png")

# %%
plt.figure(figsize=(12,8))


ax1=plt.subplot(2, 2, 1)
sns.set_style("darkgrid")
plot_pacf(df['DAC'].diff().iloc[1:].values,lags=50,ax=ax1, color="#c6474b", vlines_kwargs={"colors": "#c6474b"})
plt.xlabel('')
plt.ylabel("")
sns.despine()
plt.title("DAC (Algoritmo de Disciplinado)")


ax2=plt.subplot(2, 2, 2)

sns.set_style("darkgrid")
plot_pacf(df['Phase Error'].diff().iloc[1:].values,lags=50,ax=ax2, color="#c6474b", vlines_kwargs={"colors": "#c6474b"})
plt.xlabel('')
plt.ylabel("")
plt.title("Error de Fase (Phase Error)")
sns.despine()

ax3=plt.subplot(2, 2, 3)

sns.set_style("darkgrid")
plot_pacf(df['Temperature'].diff().iloc[1:].values,lags=50,ax=ax3, color="#c6474b", vlines_kwargs={"colors": "#c6474b"})
plt.xlabel('')
plt.ylabel("")
plt.title("Temperatura")
sns.despine()

ax4=plt.subplot(2, 2, 4)

sns.set_style("darkgrid")
plot_pacf(df['Frequency Error'].diff().iloc[1:].values,lags=50,ax=ax4, color="#c6474b", vlines_kwargs={"colors": "#c6474b"})
plt.xlabel('')
plt.ylabel("")
plt.title("Error de Frecuencia (Frequency Error)")
sns.despine()

plt.suptitle("Autocorrelación Parcial (Diferencia)", fontsize=18)
plt.tight_layout()

#plt.savefig("fotos/diff_partial_autocorrelacion.png")

# %%
plt.figure(figsize=(14,4))


ax1=plt.subplot(1, 3, 1)
sns.set_style("darkgrid")
sns.lineplot(data=pd.Series(sm.tsa.stattools.ccf(df['DAC'].values, df['Frequency Error'].values, adjusted=False))[:200], color="#c6474b")
plt.xlabel('Lag')
plt.ylim([-0.35,0.7])
plt.ylabel("Correlación")
sns.despine()
plt.title("DAC - Frequency Error")


ax2=plt.subplot(1, 3, 2)

sns.set_style("darkgrid")
sns.lineplot(data=pd.Series(sm.tsa.stattools.ccf(df['DAC'].values, df['Phase Error'].values, adjusted=False))[:200], color="#c6474b")
plt.xlabel('Lag')
plt.ylim([-0.35,0.7])

plt.ylabel("")
plt.title("DAC - Phase Error")
sns.despine()

ax3=plt.subplot(1, 3, 3)

sns.set_style("darkgrid")
sns.lineplot(data=pd.Series(sm.tsa.stattools.ccf(df['Frequency Error'].values, df['Phase Error'].values, adjusted=False))[:200], color="#c6474b")
plt.xlabel('Lag')
plt.ylim([-0.35,0.7])
plt.ylabel("")
plt.title("Frequency Error - Phase Error")
sns.despine()

plt.suptitle("Correlación Cruzada", fontsize=18)
plt.tight_layout()

#plt.savefig("fotos/cross_correlation.png")

# %%
plt.figure(figsize=(14,4))


ax1=plt.subplot(1, 3, 1)
sns.set_style("darkgrid")
sns.lineplot(data=pd.Series(sm.tsa.stattools.ccf(df['DAC'].diff().iloc[1:].values, df['Frequency Error'].diff().iloc[1:].values, adjusted=False))[:200], color="#c6474b")
plt.xlabel('Lag')
plt.ylim([-0.3,0.15])
plt.ylabel("Correlación")
sns.despine()
plt.title("DAC - Frequency Error")


ax2=plt.subplot(1, 3, 2)

sns.set_style("darkgrid")
sns.lineplot(data=pd.Series(sm.tsa.stattools.ccf(df['DAC'].diff().iloc[1:].values, df['Phase Error'].diff().iloc[1:].values, adjusted=False))[:200], color="#c6474b")
plt.xlabel('Lag')
plt.ylim([-0.3,0.15])

plt.ylabel("")
plt.title("DAC - Phase Error")
sns.despine()

ax3=plt.subplot(1, 3, 3)

sns.set_style("darkgrid")
sns.lineplot(data=pd.Series(sm.tsa.stattools.ccf(df['Frequency Error'].diff().iloc[1:].values, df['Phase Error'].diff().iloc[1:].values, adjusted=False))[:200], color="#c6474b")
plt.xlabel('Lag')
plt.ylim([-0.3,0.15])
plt.ylabel("")
plt.title("Frequency Error - Phase Error")
sns.despine()

plt.suptitle("Correlación Cruzada (Variación)", fontsize=18)
plt.tight_layout()

#plt.savefig("fotos/diff_cross_correlation.png")
